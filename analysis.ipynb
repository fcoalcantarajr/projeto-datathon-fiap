# %%
import pandas as pd

# %%
df_applicants = pd.read_json('data/applicants.json', orient='index')

df_applicants.head()
# Out:
#                                            infos_basicas  \
# 31000  {'telefone_recado': '', 'telefone': '(11) 9704...
# 31001  {'telefone_recado': '', 'telefone': '(11) 9372...
# 31002  {'telefone_recado': '', 'telefone': '(11) 9239...
# 31003  {'telefone_recado': '', 'telefone': '(11) 9810...
# 31004  {'telefone_recado': '', 'telefone': '(11) 9251...
#
#                                     informacoes_pessoais  \
# 31000  {'data_aceite': 'Cadastro anterior ao registro...
# 31001  {'data_aceite': 'Cadastro anterior ao registro...
# 31002  {'data_aceite': 'Cadastro anterior ao registro...
# 31003  {'data_aceite': 'Cadastro anterior ao registro...
# 31004  {'data_aceite': 'Cadastro anterior ao registro...
#
#                                informacoes_profissionais  \
# 31000  {'titulo_profissional': '', 'area_atuacao': ''...
# 31001  {'titulo_profissional': 'Analista Administrati...
# 31002  {'titulo_profissional': 'Administrativo | Fina...
# 31003  {'titulo_profissional': 'Área administrativa',...
# 31004  {'titulo_profissional': '', 'area_atuacao': ''...
#
#                                       formacao_e_idiomas cargo_atual  \
# 31000  {'nivel_academico': '', 'nivel_ingles': '', 'n...          {}
# 31001  {'nivel_academico': 'Ensino Superior Incomplet...          {}
# 31002  {'nivel_academico': 'Ensino Superior Completo'...          {}
# 31003  {'nivel_academico': 'Ensino Superior Incomplet...          {}
# 31004  {'nivel_academico': '', 'nivel_ingles': '', 'n...          {}
#
#                                                    cv_pt cv_en
# 31000  assistente administrativo\n\n\nsantosbatista\n...
# 31001  formação acadêmica\nensino médio (2º grau) em ...
# 31002  objetivo: área administrativa | financeira\n\n...
# 31003  formação\nensino médio completo\ninformática i...
# 31004  última atualização em 09/11/2021\n­ sp\n\nensi...

# %%
infos_basicas = pd.json_normalize(df_applicants['infos_basicas'])
informacoes_pessoais = pd.json_normalize(df_applicants['informacoes_pessoais'])
informacoes_profissionais = pd.json_normalize(df_applicants['informacoes_profissionais'])
formacao_e_idiomas = pd.json_normalize(df_applicants['formacao_e_idiomas'])
cargo_atual = pd.json_normalize(df_applicants['cargo_atual'])

df_applicants = pd.concat([infos_basicas, informacoes_pessoais, informacoes_profissionais, formacao_e_idiomas, cargo_atual], axis=1)

column_numbers = [x for x in range(df_applicants.shape[1])]
column_numbers.remove(10)
df_applicants = df_applicants.iloc[:, column_numbers]

# %%
df_applicants.to_csv('data/applicants.csv')

# %%
df_applicants = pd.read_csv('data/applicants.csv', index_col=0)
# Out:
# /tmp/ipykernel_2427/2059521093.py:1: DtypeWarning: Columns (35,36,48,53,54) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_applicants = pd.read_csv('data/applicants.csv', index_col=0)
#        telefone_recado         telefone        objetivo_profissional  \
# 0                  NaN  (11) 97048-2708                          NaN
# 1                  NaN  (11) 93723-4396      Analista Administrativo
# 2                  NaN  (11) 92399-9824  Administrativo | Financeiro
# 3                  NaN  (11) 98100-1727          Área administrativa
# 4                  NaN  (11) 92517-2678                          NaN
# ...                ...              ...                          ...
# 42477              NaN  (11) 92622-2088      Crm / Líder de Projetos
# 42478              NaN  (41) 93009-5141                          Crm
# 42479              NaN  (11) 97837-3941                          Crm
# 42480              NaN  (61) 96806-8075                          Crm
# 42481              NaN  (15) 95637-4857                          Crm
#
#               data_criacao            inserido_por  \
# 0      10-11-2021 07:29:49            Luna Correia
# 1      10-11-2021 08:56:16           Laura Pacheco
# 2      10-11-2021 09:01:00           Laura Pacheco
# 3      10-11-2021 09:08:13           Laura Pacheco
# 4      10-11-2021 09:18:46       Maria Clara Pires
# ...                    ...                     ...
# 42477  14-03-2018 16:35:14  pelo próprio candidato
# 42478  14-03-2018 16:38:28  pelo próprio candidato
# 42479  14-03-2018 16:41:52  pelo próprio candidato
# 42480  14-03-2018 16:42:49  pelo próprio candidato
# 42481  14-03-2018 16:47:27  pelo próprio candidato
#
#                                    email                 local  \
# 0           carolina_aparecida@gmail.com                   NaN
# 1               eduardo_rios@hotmail.com  São Paulo, São Paulo
# 2      pedro_henrique_carvalho@gmail.com  São Paulo, São Paulo
# 3             thiago_barbosa@hotmail.com  São Paulo, São Paulo
# 4            diogo_das_neves@hotmail.com                   NaN
# ...                                  ...                   ...
# 42477         gabrielly_novaes@gmail.com                   NaN
# 42478         sr._gabriel_rios@gmail.com                   NaN
# 42479     dr._mathias_da_cunha@gmail.com                   NaN
# 42480           bruna_vieira@hotmail.com                   NaN
# 42481        heitor_mendonça@hotmail.com                   NaN
#
#       sabendo_de_nos_por     data_atualizacao  codigo_profissional  ...  \
# 0                    NaN  10-11-2021 07:29:49                31000  ...
# 1                 Outros  11-11-2021 11:10:31                31001  ...
# 2                Anúncio  10-11-2021 11:42:36                31002  ...
# 3       Site de Empregos  10-11-2021 16:04:51                31003  ...
# 4                    NaN  10-11-2021 09:22:03                31004  ...
# ...                  ...                  ...                  ...  ...
# 42477             Outros  14-03-2018 16:35:14                 5995  ...
# 42478             Outros  14-03-2018 16:38:28                 5996  ...
# 42479             Outros  14-03-2018 16:41:52                 5997  ...
# 42480             Outros  14-03-2018 16:42:49                 5998  ...
# 42481             Outros  14-03-2018 16:47:27                 5999  ...
#
#       id_ibrati email_corporativo  cargo_atual projeto_atual cliente  unidade  \
# 0           NaN               NaN          NaN           NaN     NaN      NaN
# 1           NaN               NaN          NaN           NaN     NaN      NaN
# 2           NaN               NaN          NaN           NaN     NaN      NaN
# 3           NaN               NaN          NaN           NaN     NaN      NaN
# 4           NaN               NaN          NaN           NaN     NaN      NaN
# ...         ...               ...          ...           ...     ...      ...
# 42477       NaN               NaN          NaN           NaN     NaN      NaN
# 42478       NaN               NaN          NaN           NaN     NaN      NaN
# 42479       NaN               NaN          NaN           NaN     NaN      NaN
# 42480       NaN               NaN          NaN           NaN     NaN      NaN
# 42481       NaN               NaN          NaN           NaN     NaN      NaN
#
#       data_admissao data_ultima_promocao  nome_superior_imediato  \
# 0               NaN                  NaN                     NaN
# 1               NaN                  NaN                     NaN
# 2               NaN                  NaN                     NaN
# 3               NaN                  NaN                     NaN
# 4               NaN                  NaN                     NaN
# ...             ...                  ...                     ...
# 42477           NaN                  NaN                     NaN
# 42478           NaN                  NaN                     NaN
# 42479           NaN                  NaN                     NaN
# 42480           NaN                  NaN                     NaN
# 42481           NaN                  NaN                     NaN
#
#       email_superior_imediato
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 42477                     NaN
# 42478                     NaN
# 42479                     NaN
# 42480                     NaN
# 42481                     NaN
#
# [42482 rows x 54 columns]

# %%
df_prospects = pd.read_json('data/prospects.json', orient='index')

df_prospects
# Out:
#                                                   titulo modalidade  \
# 4530                                 CONSULTOR CONTROL M
# 4531   2021-2607395-PeopleSoft Application Engine-Dom...
# 4532
# 4533   2021-2605708-Microfocus Application Life Cycle...
# 4534   2021-2605711-Microfocus QTP - UFT Automation T...
# ...                                                  ...        ...
# 14218                               Java Support Analyst
# 14219
# 14220   Consultor Sênior Especialista SAP LES-TRA - 1433
# 14221            Consultor Sênior Oracle EPM FCCS - 1434
# 14222
#
#                                                prospects
# 4530   [{'nome': 'José Vieira', 'codigo': '25632', 's...
# 4531   [{'nome': 'Sra. Yasmin Fernandes', 'codigo': '...
# 4532                                                  []
# 4533   [{'nome': 'Arthur Almeida', 'codigo': '26338',...
# 4534   [{'nome': 'Ana Luiza Vieira', 'codigo': '26361...
# ...                                                  ...
# 14218  [{'nome': 'Dr. Vitor Hugo Silva', 'codigo': '4...
# 14219                                                 []
# 14220  [{'nome': 'Ana Cardoso', 'codigo': '16828', 's...
# 14221  [{'nome': 'Maria Eduarda Cassiano', 'codigo': ...
# 14222                                                 []
#
# [14222 rows x 3 columns]

# %%
# Read the JSON file
df_prospects = pd.read_json('data/prospects.json', orient='index')

# Ensure 'prospects' column exists for all rows
df_prospects['prospects'] = df_prospects.get('prospects', pd.Series([[]]*len(df_prospects), index=df_prospects.index))

# Explode the 'prospects' list so each prospect gets its own row
df_exploded = df_prospects.explode('prospects')

# Drop rows where 'prospects' is still empty (i.e., NaN after explode)
df_exploded = df_exploded.dropna(subset=['prospects'])

# Normalize the 'prospects' dictionaries into columns
if not df_exploded.empty:
    df_normalized = pd.json_normalize(df_exploded['prospects'])
    # Combine with the index (IDs)
    df_result = df_exploded.drop(columns=['prospects']).join(df_normalized)
else:
    df_result = pd.DataFrame()  # No prospects to normalize

df_result.head()
# Out:
#                                                  titulo modalidade  \
# 4530                                CONSULTOR CONTROL M
# 4530                                CONSULTOR CONTROL M
# 4531  2021-2607395-PeopleSoft Application Engine-Dom...
# 4531  2021-2607395-PeopleSoft Application Engine-Dom...
# 4533  2021-2605708-Microfocus Application Life Cycle...
#
#                        nome codigo  situacao_candidado data_candidatura  \
# 4530         Kaique Almeida  34491  Entrevista Técnica       30-03-2022
# 4530         Kaique Almeida  34491  Entrevista Técnica       30-03-2022
# 4531  Dr. Luiz Otávio Viana  34162            Prospect       17-03-2022
# 4531  Dr. Luiz Otávio Viana  34162            Prospect       17-03-2022
# 4533          Ryan Cassiano  13960            Prospect       04-04-2022
#
#      ultima_atualizacao                comentario            recrutador
# 4530         13-04-2022  Avaliação pela  em 13/04         Elisa Barbosa
# 4530         13-04-2022  Avaliação pela  em 13/04         Elisa Barbosa
# 4531         17-03-2022                                  Yasmin da Rosa
# 4531         17-03-2022                                  Yasmin da Rosa
# 4533         04-04-2022                            Srta. Bella Ferreira

# %%
df_prospects = df_result

# %%
df_prospects
# Out:
#                                                   titulo modalidade  \
# 4530                                 CONSULTOR CONTROL M
# 4530                                 CONSULTOR CONTROL M
# 4531   2021-2607395-PeopleSoft Application Engine-Dom...
# 4531   2021-2607395-PeopleSoft Application Engine-Dom...
# 4533   2021-2605708-Microfocus Application Life Cycle...
# ...                                                  ...        ...
# 14217                                             SAP SD
# 14218                               Java Support Analyst
# 14220   Consultor Sênior Especialista SAP LES-TRA - 1433
# 14220   Consultor Sênior Especialista SAP LES-TRA - 1433
# 14221            Consultor Sênior Oracle EPM FCCS - 1434
#
#                           nome codigo              situacao_candidado  \
# 4530            Kaique Almeida  34491              Entrevista Técnica
# 4530            Kaique Almeida  34491              Entrevista Técnica
# 4531     Dr. Luiz Otávio Viana  34162                        Prospect
# 4531     Dr. Luiz Otávio Viana  34162                        Prospect
# 4533             Ryan Cassiano  13960                        Prospect
# ...                        ...    ...                             ...
# 14217         Amanda Gonçalves  14289  Não Aprovado pelo Requisitante
# 14218  Ana Vitória Albuquerque  14245                        Inscrito
# 14220           Miguel Pereira  14213     Encaminhado ao Requisitante
# 14220           Miguel Pereira  14213     Encaminhado ao Requisitante
# 14221             Luan Marques   3217     Encaminhado ao Requisitante
#
#       data_candidatura ultima_atualizacao  \
# 4530        30-03-2022         13-04-2022
# 4530        30-03-2022         13-04-2022
# 4531        17-03-2022         17-03-2022
# 4531        17-03-2022         17-03-2022
# 4533        04-04-2022         04-04-2022
# ...                ...                ...
# 14217       22-02-2019         26-02-2019
# 14218       20-02-2019
# 14220       19-02-2019         19-02-2019
# 14220       19-02-2019         19-02-2019
# 14221       19-02-2019         19-02-2019
#
#                                               comentario            recrutador
# 4530                            Avaliação pela  em 13/04         Elisa Barbosa
# 4530                            Avaliação pela  em 13/04         Elisa Barbosa
# 4531                                                            Yasmin da Rosa
# 4531                                                            Yasmin da Rosa
# 4533                                                      Srta. Bella Ferreira
# ...                                                  ...                   ...
# 14217  A experiência da Ana é muito pequena ( nível j...         Helena Barros
# 14218                                                         Caroline Machado
# 14220  Modalidade: Cooperado Valor de compra: R$ 60,0...  Srta. Bella Ferreira
# 14220  Modalidade: Cooperado Valor de compra: R$ 60,0...  Srta. Bella Ferreira
# 14221  Modalidade: Cooperado Valor de compra: R$ 50,0...  Srta. Bella Ferreira
#
# [53759 rows x 9 columns]

# %% [markdown]
# #### Temos df_applicants, df_prospects agora.

# %%
# Read the JSON file as a dictionary of dictionaries
df_vagas = pd.read_json('data/vagas.json', orient='index')

# Normalize each dictionary column
infos_basicas = pd.json_normalize(df_vagas['informacoes_basicas'])
perfil_vaga = pd.json_normalize(df_vagas['perfil_vaga'])
beneficios = pd.json_normalize(df_vagas['beneficios'])

# Concatenate all normalized columns with the original index
df_vagas = pd.concat([infos_basicas, perfil_vaga, beneficios], axis=1)

# Show the flattened DataFrame
df_vagas
# Out:
#       data_requicisao limite_esperado_para_contratacao  \
# 0          04-05-2021                       00-00-0000
# 1          04-05-2021                       00-00-0000
# 2          04-05-2021                       00-00-0000
# 3          04-05-2021                       18-05-2021
# 4          04-05-2021                       00-00-0000
# ...               ...                              ...
# 14076      28-02-2024                       31-03-2024
# 14077      28-02-2024                       29-02-2024
# 14078      27-02-2024                       29-02-2024
# 14079      27-02-2024                       29-02-2024
# 14080      27-02-2024                       29-02-2024
#
#                                              titulo_vaga vaga_sap  \
# 0                                       Operation Lead -      Não
# 1                                 Consultor PP/QM Sênior      Não
# 2                                  ANALISTA PL/JR C/ SQL      Não
# 3                         Technical Architect - 11894809      Não
# 4      Consultor SAP AUTHORIZATION (BCA) -Pleno / Sênior      Não
# ...                                                  ...      ...
# 14076                             PMP 5203658 - Dynamics      Não
# 14077                               MM com IM - FSR 3910      Não
# 14078              964 - Assistente fiscal ou financeiro      Não
# 14079      966 - Analista pleno ou sênior de área fiscal      Não
# 14080      965 - Assistente ou analista de área contábil      Não
#
#                          cliente    solicitante_cliente     empresa_divisao  \
# 0       Morris, Moran and Dodson  Dra. Catarina Marques  Decision São Paulo
# 1       Morris, Moran and Dodson  Dra. Catarina Marques  Decision São Paulo
# 2       Morris, Moran and Dodson  Dra. Catarina Marques  Decision São Paulo
# 3                    Nelson-Page      Dr. Raul Monteiro  Decision São Paulo
# 4                  Mann and Sons            Cauê Fogaça  Decision São Paulo
# ...                          ...                    ...                 ...
# 14076               Miller-Curry       Guilherme Campos   Decision Campinas
# 14077                Bishop-Reed      Lívia Vasconcelos  Decision São Paulo
# 14078  Glover, Warren and Norris          Lorenzo Cunha  Decision São Paulo
# 14079  Glover, Warren and Norris          Lorenzo Cunha  Decision São Paulo
# 14080  Glover, Warren and Norris          Lorenzo Cunha  Decision São Paulo
#
#                 requisitante  analista_responsavel       tipo_contratacao  \
# 0       Maria Laura Nogueira  Srta. Bella Ferreira               CLT Full
# 1       Maria Laura Nogueira        Yasmin da Rosa               CLT Full
# 2       Maria Laura Nogueira       Ana Albuquerque               CLT Full
# 3            Cecília Freitas            Clara Rios  PJ/Autônomo, CLT Full
# 4       Maria Laura Nogueira  Srta. Bella Ferreira               CLT Full
# ...                      ...                   ...                    ...
# 14076  Sra. Juliana Oliveira      Sra. Joana Sousa               CLT Full
# 14077         Manuella Jesus  Srta. Bella Ferreira  CLT Full, PJ/Autônomo
# 14078            Maria Lopes     Maria Clara Pires  CLT Full, PJ/Autônomo
# 14079            Maria Lopes     Melina Montenegro  CLT Full, PJ/Autônomo
# 14080            Maria Lopes         Laura Pacheco  CLT Full, PJ/Autônomo
#
#        ...                      areas_atuacao  \
# 0      ...       TI - Sistemas e Ferramentas-
# 1      ...  TI - Desenvolvimento/Programação-
# 2      ...       TI - Sistemas e Ferramentas-
# 3      ...                     TI - Projetos-
# 4      ...                          TI - SAP-
# ...    ...                                ...
# 14076  ...  TI - Desenvolvimento/Programação-
# 14077  ...                     TI - Projetos-
# 14078  ...                     TI - Projetos-
# 14079  ...                     TI - Projetos-
# 14080  ...                     TI - Projetos-
#
#                                    principais_atividades  \
# 0      Operations Lead\n\nRoles & Responsibilities:\n...
# 1      Consultor PP/QM Sr.\n\n• Consultor PP/QM Sênio...
# 2      Descrição – Atividades:\n\no Monitoramento das...
# 3      Descrição/Comentário: Architecture Frameworks ...
# 4      Experiência como Consultor SAP AUTHORIZATION (...
# ...                                                  ...
# 14076                                           Dynamics
# 14077  1 Deve ter boa experiência em configuração de ...
# 14078  Qualificações técnicas: conhecimento básico em...
# 14079  Qualificações técnicas: apuração de impostos r...
# 14080  Qualificações técnicas: reconciliação de conta...
#
#                   competencia_tecnicas_e_comportamentais  \
# 0      Required Skills:\n• Prior experience in Cloud ...
# 1      • Consultor PP/QM Sênior com experiencia em pr...
# 2      Requisitos mandatórios:\n\no Conhecimentos Téc...
# 3      Descrição/Comentário: Architecture Frameworks ...
# 4      Experiência como Consultor SAP AUTHORIZATION (...
# ...                                                  ...
# 14076                                           Dynamics
# 14077  inglês avançado: (tem que se comunicar com o G...
# 14078  Local: Alphaville, Barueri\nQual região: SP\nI...
# 14079  Local: Alphaville, Barueri, SP.\nQual região: ...
# 14080  Local: Alphaville, Barueri, SP.\nRegião: Grand...
#
#                                       demais_observacoes viagens_requeridas  \
# 0                100% Remoto Período – entre 5 – 6 meses
# 1                       • Início: Imediato • Fim: Jan/22
# 2      Localização: Remoto Perfil: Analista Pleno ou ...
# 3      Budgeted Rate - indicate currency and type (ho...                Não
# 4      contratação CLT full pela Decision locação rem...                Sim
# ...                                                  ...                ...
# 14076
# 14077                                          FSR: 3910                Não
# 14078  Modelo de trabalho: Hibrido, 3 vezes por seman...                Não
# 14079  Modelo de trabalho: Hibrido, 3 vezes por seman...                Não
# 14080  Modelo de trabalho: Hibrido, 3 vezes por seman...                Não
#
#       equipamentos_necessarios habilidades_comportamentais_necessarias  \
# 0                     Nenhum -                                     NaN
# 1                     Nenhum -                                     NaN
# 2                     Nenhum -                                     NaN
# 3            Notebook padrão -                                     NaN
# 4                     Nenhum -                                     NaN
# ...                        ...                                     ...
# 14076                                                              NaN
# 14077                                                              NaN
# 14078                                                              NaN
# 14079                                                              NaN
# 14080                                                              NaN
#
#            valor_venda                                     valor_compra_1  \
# 0                    -                                                 R$
# 1                    -                                                 R$
# 2                    -                                                 R$
# 3      - p/ mês (168h)                                            fechado
# 4                    -                                                 R$
# ...                ...                                                ...
# 14076         123,00 -  APPLICATION DEVELOPER-MICROSOFT ANALYTICS - ba...
# 14077            168 -                                            Fechado
# 14078            168 -                                            Fechado
# 14079            168 -                                            Fechado
# 14080            168 -                                            Fechado
#
#       valor_compra_2
# 0
# 1
# 2
# 3
# 4
# ...              ...
# 14076
# 14077
# 14078
# 14079
# 14080
#
# [14081 rows x 44 columns]

# %%
df_vagas
# Out:
#       data_requicisao limite_esperado_para_contratacao  \
# 0          04-05-2021                       00-00-0000
# 1          04-05-2021                       00-00-0000
# 2          04-05-2021                       00-00-0000
# 3          04-05-2021                       18-05-2021
# 4          04-05-2021                       00-00-0000
# ...               ...                              ...
# 14076      28-02-2024                       31-03-2024
# 14077      28-02-2024                       29-02-2024
# 14078      27-02-2024                       29-02-2024
# 14079      27-02-2024                       29-02-2024
# 14080      27-02-2024                       29-02-2024
#
#                                              titulo_vaga vaga_sap  \
# 0                                       Operation Lead -      Não
# 1                                 Consultor PP/QM Sênior      Não
# 2                                  ANALISTA PL/JR C/ SQL      Não
# 3                         Technical Architect - 11894809      Não
# 4      Consultor SAP AUTHORIZATION (BCA) -Pleno / Sênior      Não
# ...                                                  ...      ...
# 14076                             PMP 5203658 - Dynamics      Não
# 14077                               MM com IM - FSR 3910      Não
# 14078              964 - Assistente fiscal ou financeiro      Não
# 14079      966 - Analista pleno ou sênior de área fiscal      Não
# 14080      965 - Assistente ou analista de área contábil      Não
#
#                          cliente    solicitante_cliente     empresa_divisao  \
# 0       Morris, Moran and Dodson  Dra. Catarina Marques  Decision São Paulo
# 1       Morris, Moran and Dodson  Dra. Catarina Marques  Decision São Paulo
# 2       Morris, Moran and Dodson  Dra. Catarina Marques  Decision São Paulo
# 3                    Nelson-Page      Dr. Raul Monteiro  Decision São Paulo
# 4                  Mann and Sons            Cauê Fogaça  Decision São Paulo
# ...                          ...                    ...                 ...
# 14076               Miller-Curry       Guilherme Campos   Decision Campinas
# 14077                Bishop-Reed      Lívia Vasconcelos  Decision São Paulo
# 14078  Glover, Warren and Norris          Lorenzo Cunha  Decision São Paulo
# 14079  Glover, Warren and Norris          Lorenzo Cunha  Decision São Paulo
# 14080  Glover, Warren and Norris          Lorenzo Cunha  Decision São Paulo
#
#                 requisitante  analista_responsavel       tipo_contratacao  \
# 0       Maria Laura Nogueira  Srta. Bella Ferreira               CLT Full
# 1       Maria Laura Nogueira        Yasmin da Rosa               CLT Full
# 2       Maria Laura Nogueira       Ana Albuquerque               CLT Full
# 3            Cecília Freitas            Clara Rios  PJ/Autônomo, CLT Full
# 4       Maria Laura Nogueira  Srta. Bella Ferreira               CLT Full
# ...                      ...                   ...                    ...
# 14076  Sra. Juliana Oliveira      Sra. Joana Sousa               CLT Full
# 14077         Manuella Jesus  Srta. Bella Ferreira  CLT Full, PJ/Autônomo
# 14078            Maria Lopes     Maria Clara Pires  CLT Full, PJ/Autônomo
# 14079            Maria Lopes     Melina Montenegro  CLT Full, PJ/Autônomo
# 14080            Maria Lopes         Laura Pacheco  CLT Full, PJ/Autônomo
#
#        ...                      areas_atuacao  \
# 0      ...       TI - Sistemas e Ferramentas-
# 1      ...  TI - Desenvolvimento/Programação-
# 2      ...       TI - Sistemas e Ferramentas-
# 3      ...                     TI - Projetos-
# 4      ...                          TI - SAP-
# ...    ...                                ...
# 14076  ...  TI - Desenvolvimento/Programação-
# 14077  ...                     TI - Projetos-
# 14078  ...                     TI - Projetos-
# 14079  ...                     TI - Projetos-
# 14080  ...                     TI - Projetos-
#
#                                    principais_atividades  \
# 0      Operations Lead\n\nRoles & Responsibilities:\n...
# 1      Consultor PP/QM Sr.\n\n• Consultor PP/QM Sênio...
# 2      Descrição – Atividades:\n\no Monitoramento das...
# 3      Descrição/Comentário: Architecture Frameworks ...
# 4      Experiência como Consultor SAP AUTHORIZATION (...
# ...                                                  ...
# 14076                                           Dynamics
# 14077  1 Deve ter boa experiência em configuração de ...
# 14078  Qualificações técnicas: conhecimento básico em...
# 14079  Qualificações técnicas: apuração de impostos r...
# 14080  Qualificações técnicas: reconciliação de conta...
#
#                   competencia_tecnicas_e_comportamentais  \
# 0      Required Skills:\n• Prior experience in Cloud ...
# 1      • Consultor PP/QM Sênior com experiencia em pr...
# 2      Requisitos mandatórios:\n\no Conhecimentos Téc...
# 3      Descrição/Comentário: Architecture Frameworks ...
# 4      Experiência como Consultor SAP AUTHORIZATION (...
# ...                                                  ...
# 14076                                           Dynamics
# 14077  inglês avançado: (tem que se comunicar com o G...
# 14078  Local: Alphaville, Barueri\nQual região: SP\nI...
# 14079  Local: Alphaville, Barueri, SP.\nQual região: ...
# 14080  Local: Alphaville, Barueri, SP.\nRegião: Grand...
#
#                                       demais_observacoes viagens_requeridas  \
# 0                100% Remoto Período – entre 5 – 6 meses
# 1                       • Início: Imediato • Fim: Jan/22
# 2      Localização: Remoto Perfil: Analista Pleno ou ...
# 3      Budgeted Rate - indicate currency and type (ho...                Não
# 4      contratação CLT full pela Decision locação rem...                Sim
# ...                                                  ...                ...
# 14076
# 14077                                          FSR: 3910                Não
# 14078  Modelo de trabalho: Hibrido, 3 vezes por seman...                Não
# 14079  Modelo de trabalho: Hibrido, 3 vezes por seman...                Não
# 14080  Modelo de trabalho: Hibrido, 3 vezes por seman...                Não
#
#       equipamentos_necessarios habilidades_comportamentais_necessarias  \
# 0                     Nenhum -                                     NaN
# 1                     Nenhum -                                     NaN
# 2                     Nenhum -                                     NaN
# 3            Notebook padrão -                                     NaN
# 4                     Nenhum -                                     NaN
# ...                        ...                                     ...
# 14076                                                              NaN
# 14077                                                              NaN
# 14078                                                              NaN
# 14079                                                              NaN
# 14080                                                              NaN
#
#            valor_venda                                     valor_compra_1  \
# 0                    -                                                 R$
# 1                    -                                                 R$
# 2                    -                                                 R$
# 3      - p/ mês (168h)                                            fechado
# 4                    -                                                 R$
# ...                ...                                                ...
# 14076         123,00 -  APPLICATION DEVELOPER-MICROSOFT ANALYTICS - ba...
# 14077            168 -                                            Fechado
# 14078            168 -                                            Fechado
# 14079            168 -                                            Fechado
# 14080            168 -                                            Fechado
#
#       valor_compra_2
# 0
# 1
# 2
# 3
# 4
# ...              ...
# 14076
# 14077
# 14078
# 14079
# 14080
#
# [14081 rows x 44 columns]

# %% [markdown]
# #### Temos df_applicants, df_prospects e df_vagas agora.

# %% [markdown]
# ##### Esta aplicação visa ranquear os 10 melhores candidatos para cada vaga.

# %%
df_vagas.columns
# Out:
# Index(['data_requicisao', 'limite_esperado_para_contratacao', 'titulo_vaga',
#        'vaga_sap', 'cliente', 'solicitante_cliente', 'empresa_divisao',
#        'requisitante', 'analista_responsavel', 'tipo_contratacao',
#        'prazo_contratacao', 'objetivo_vaga', 'prioridade_vaga', 'origem_vaga',
#        'superior_imediato', 'nome', 'telefone', 'data_inicial', 'data_final',
#        'nome_substituto', 'pais', 'estado', 'cidade', 'bairro', 'regiao',
#        'local_trabalho', 'vaga_especifica_para_pcd', 'faixa_etaria',
#        'horario_trabalho', 'nivel profissional', 'nivel_academico',
#        'nivel_ingles', 'nivel_espanhol', 'outro_idioma', 'areas_atuacao',
#        'principais_atividades', 'competencia_tecnicas_e_comportamentais',
#        'demais_observacoes', 'viagens_requeridas', 'equipamentos_necessarios',
#        'habilidades_comportamentais_necessarias', 'valor_venda',
#        'valor_compra_1', 'valor_compra_2'],
#       dtype='object')

# %%
df_vagas.titulo_vaga
# Out:
# 0                                         Operation Lead -
# 1                                   Consultor PP/QM Sênior
# 2                                    ANALISTA PL/JR C/ SQL
# 3                           Technical Architect - 11894809
# 4        Consultor SAP AUTHORIZATION (BCA) -Pleno / Sênior
#                                ...
# 14076                               PMP 5203658 - Dynamics
# 14077                                 MM com IM - FSR 3910
# 14078                964 - Assistente fiscal ou financeiro
# 14079        966 - Analista pleno ou sênior de área fiscal
# 14080        965 - Assistente ou analista de área contábil
# Name: titulo_vaga, Length: 14081, dtype: object

# %%
df_vagas.nivel_espanhol.value_counts()
# Out:
# nivel_espanhol
# Nenhum           6152
# Básico           5821
#                  1304
# Avançado          332
# Intermediário     234
# Fluente           227
# Técnico            11
# Name: count, dtype: int64

# %%
df_vagas_filtered = df_vagas[['titulo_vaga','cidade','nivel profissional','nivel_ingles','nivel_espanhol','areas_atuacao','principais_atividades','competencia_tecnicas_e_comportamentais','demais_observacoes','habilidades_comportamentais_necessarias']]
df_vagas_filtered
# Out:
#                                              titulo_vaga     cidade  \
# 0                                       Operation Lead -  São Paulo
# 1                                 Consultor PP/QM Sênior  São Paulo
# 2                                  ANALISTA PL/JR C/ SQL  São Paulo
# 3                         Technical Architect - 11894809  São Paulo
# 4      Consultor SAP AUTHORIZATION (BCA) -Pleno / Sênior  São Paulo
# ...                                                  ...        ...
# 14076                             PMP 5203658 - Dynamics  São Paulo
# 14077                               MM com IM - FSR 3910  São Paulo
# 14078              964 - Assistente fiscal ou financeiro  São Paulo
# 14079      966 - Analista pleno ou sênior de área fiscal    Barueri
# 14080      965 - Assistente ou analista de área contábil    Barueri
#
#       nivel profissional   nivel_ingles nivel_espanhol  \
# 0                 Sênior       Avançado        Fluente
# 1                 Sênior        Fluente         Nenhum
# 2               Analista         Nenhum  Intermediário
# 3               Analista         Básico         Básico
# 4                 Sênior  Intermediário         Nenhum
# ...                  ...            ...            ...
# 14076           Analista         Nenhum
# 14077           Analista       Avançado         Básico
# 14078           Analista         Básico         Básico
# 14079             Sênior         Básico         Básico
# 14080           Analista         Básico         Básico
#
#                            areas_atuacao  \
# 0           TI - Sistemas e Ferramentas-
# 1      TI - Desenvolvimento/Programação-
# 2           TI - Sistemas e Ferramentas-
# 3                         TI - Projetos-
# 4                              TI - SAP-
# ...                                  ...
# 14076  TI - Desenvolvimento/Programação-
# 14077                     TI - Projetos-
# 14078                     TI - Projetos-
# 14079                     TI - Projetos-
# 14080                     TI - Projetos-
#
#                                    principais_atividades  \
# 0      Operations Lead\n\nRoles & Responsibilities:\n...
# 1      Consultor PP/QM Sr.\n\n• Consultor PP/QM Sênio...
# 2      Descrição – Atividades:\n\no Monitoramento das...
# 3      Descrição/Comentário: Architecture Frameworks ...
# 4      Experiência como Consultor SAP AUTHORIZATION (...
# ...                                                  ...
# 14076                                           Dynamics
# 14077  1 Deve ter boa experiência em configuração de ...
# 14078  Qualificações técnicas: conhecimento básico em...
# 14079  Qualificações técnicas: apuração de impostos r...
# 14080  Qualificações técnicas: reconciliação de conta...
#
#                   competencia_tecnicas_e_comportamentais  \
# 0      Required Skills:\n• Prior experience in Cloud ...
# 1      • Consultor PP/QM Sênior com experiencia em pr...
# 2      Requisitos mandatórios:\n\no Conhecimentos Téc...
# 3      Descrição/Comentário: Architecture Frameworks ...
# 4      Experiência como Consultor SAP AUTHORIZATION (...
# ...                                                  ...
# 14076                                           Dynamics
# 14077  inglês avançado: (tem que se comunicar com o G...
# 14078  Local: Alphaville, Barueri\nQual região: SP\nI...
# 14079  Local: Alphaville, Barueri, SP.\nQual região: ...
# 14080  Local: Alphaville, Barueri, SP.\nRegião: Grand...
#
#                                       demais_observacoes  \
# 0                100% Remoto Período – entre 5 – 6 meses
# 1                       • Início: Imediato • Fim: Jan/22
# 2      Localização: Remoto Perfil: Analista Pleno ou ...
# 3      Budgeted Rate - indicate currency and type (ho...
# 4      contratação CLT full pela Decision locação rem...
# ...                                                  ...
# 14076
# 14077                                          FSR: 3910
# 14078  Modelo de trabalho: Hibrido, 3 vezes por seman...
# 14079  Modelo de trabalho: Hibrido, 3 vezes por seman...
# 14080  Modelo de trabalho: Hibrido, 3 vezes por seman...
#
#       habilidades_comportamentais_necessarias
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 14076                                     NaN
# 14077                                     NaN
# 14078                                     NaN
# 14079                                     NaN
# 14080                                     NaN
#
# [14081 rows x 10 columns]

# %%
df_applicants.columns
# Out:
# Index(['telefone_recado', 'telefone', 'objetivo_profissional', 'data_criacao',
#        'inserido_por', 'email', 'local', 'sabendo_de_nos_por',
#        'data_atualizacao', 'codigo_profissional', 'data_aceite', 'nome', 'cpf',
#        'fonte_indicacao', 'email', 'email_secundario', 'data_nascimento',
#        'telefone_celular', 'telefone_recado', 'sexo', 'estado_civil', 'pcd',
#        'endereco', 'skype', 'url_linkedin', 'facebook', 'download_cv',
#        'titulo_profissional', 'area_atuacao', 'conhecimentos_tecnicos',
#        'certificacoes', 'outras_certificacoes', 'remuneracao',
#        'nivel_profissional', 'qualificacoes', 'experiencias',
#        'nivel_academico', 'nivel_ingles', 'nivel_espanhol', 'outro_idioma',
#        'instituicao_ensino_superior', 'cursos', 'ano_conclusao', 'outro_curso',
#        'id_ibrati', 'email_corporativo', 'cargo_atual', 'projeto_atual',
#        'cliente', 'unidade', 'data_admissao', 'data_ultima_promocao',
#        'nome_superior_imediato', 'email_superior_imediato'],
#       dtype='object')

# %%
df_applicants_filtered = df_applicants[['nome','endereco','titulo_profissional','area_atuacao','conhecimentos_tecnicos','certificacoes','outras_certificacoes','nivel_profissional','nivel_ingles','nivel_espanhol']]
df_applicants_filtered
# Out:
#                           nome   endereco          titulo_profissional  \
# 0           Carolina Aparecida
# 1                 Eduardo Rios  são paulo      Analista Administrativo
# 2      Pedro Henrique Carvalho  são paulo  Administrativo | Financeiro
# 3               Thiago Barbosa  são paulo          Área administrativa
# 4              Diogo das Neves
# ...                        ...        ...                          ...
# 42477         Gabrielly Novaes                 Crm / Líder de Projetos
# 42478         Sr. Gabriel Rios                                     Crm
# 42479     Dr. Mathias da Cunha                                     Crm
# 42480             Bruna Vieira                                     Crm
# 42481          Heitor Mendonça                                     Crm
#
#          area_atuacao conhecimentos_tecnicos  \
# 0
# 1      Administrativa
# 2      Administrativa
# 3      Administrativa
# 4
# ...               ...                    ...
# 42477
# 42478
# 42479
# 42480
# 42481
#
#                                            certificacoes outras_certificacoes  \
# 0
# 1
# 2      MS [77-418] MOS: Microsoft Office Word 2013, M...
# 3
# 4
# ...                                                  ...                  ...
# 42477
# 42478
# 42479
# 42480
# 42481
#
#       nivel_profissional   nivel_ingles nivel_espanhol
# 0
# 1                                Nenhum         Nenhum
# 2                         Intermediário         Básico
# 3                                Nenhum         Nenhum
# 4
# ...                  ...            ...            ...
# 42477
# 42478
# 42479
# 42480
# 42481
#
# [42482 rows x 10 columns]

# %% [markdown]
# ##### Usar df_applicants_filtered e df_vagas_filtered para fazer o match entre candidatos e vagas

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Dictionary to store TF-IDF matrices for applicants
tfidf_applicants = {}

# Iterate through each column of df_applicants_filtered
for col in df_applicants_filtered.columns:
    # Fit and transform the text data
    tfidf_applicants[col] = tfidf_vectorizer.fit_transform(df_applicants_filtered[col])

# Dictionary to store TF-IDF matrices for vagas
tfidf_vagas = {}

# Iterate through each column of df_vagas_filtered
for col in df_vagas_filtered.columns:
    # Fit and transform the text data
    tfidf_vagas[col] = tfidf_vectorizer.fit_transform(df_vagas_filtered[col])

print("TF-IDF matrices for applicants:")
print(tfidf_applicants.keys())
print("\nTF-IDF matrices for vagas:")
print(tfidf_vagas.keys())
# Out:
# TF-IDF matrices for applicants:
# dict_keys(['nome', 'endereco', 'titulo_profissional', 'area_atuacao', 'conhecimentos_tecnicos', 'certificacoes', 'outras_certificacoes', 'nivel_profissional', 'nivel_ingles', 'nivel_espanhol'])
#
# TF-IDF matrices for vagas:
# dict_keys(['titulo_vaga', 'cidade', 'nivel profissional', 'nivel_ingles', 'nivel_espanhol', 'areas_atuacao', 'principais_atividades', 'competencia_tecnicas_e_comportamentais', 'demais_observacoes', 'habilidades_comportamentais_necessarias'])

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Download necessary NLTK data
nltk.download('stopwords')
nltk.download('wordnet')

# Initialize stop words for Portuguese and lemmatizer
stop_words = set(stopwords.words('portuguese'))
lemmatizer = WordNetLemmatizer()

# Function to clean text: remove non-alphanumeric characters, lowercase, lemmatize, and remove stop words
def clean_text(text):
    if isinstance(text, str):
        # Remove non-alphanumeric characters
        text = re.sub(r'[^\w\s]', '', text, re.UNICODE)
        # Lowercase the text
        text = text.lower()
        # Split the text into words, lemmatize each word, and join them back into a string
        text = [lemmatizer.lemmatize(token) for token in text.split(" ")]
        text = [lemmatizer.lemmatize(token, "v") for token in text]
        # Remove stop words
        text = [word for word in text if not word in stop_words]
        # Join the cleaned words
        text = " ".join(text)
        return text
    else:
        return ''

# Apply the cleaning function to all object columns in df_applicants_filtered
for col in df_applicants_filtered.columns:
    if df_applicants_filtered[col].dtype == 'object':
        df_applicants_filtered[col] = df_applicants_filtered[col].astype(str).apply(clean_text)

# Apply the cleaning function to all object columns in df_vagas_filtered
for col in df_vagas_filtered.columns:
    if df_vagas_filtered[col].dtype == 'object':
        df_vagas_filtered[col] = df_vagas_filtered[col].astype(str).apply(clean_text)

# Print the head of the cleaned dataframes
print("Cleaned df_applicants_filtered:")
print(df_applicants_filtered.head())
print("\nCleaned df_vagas_filtered:")
print(df_vagas_filtered.head())
# Out:
# [nltk_data] Downloading package stopwords to /home/vscode/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/vscode/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# /tmp/ipykernel_626/2126122218.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_applicants_filtered[col] = df_applicants_filtered[col].astype(str).apply(clean_text)
# /tmp/ipykernel_626/2126122218.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_applicants_filtered[col] = df_applicants_filtered[col].astype(str).apply(clean_text)
# /tmp/ipykernel_626/2126122218.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_applicants_filtered[col] = df_applicants_filtered[col].astype(str).apply(clean_text)
# /tmp/ipykernel_626/2126122218.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_applicants_filtered[col] = df_applicants_filtered[col].astype(str).apply(clean_text)
# /tmp/ipykernel_626/2126122218.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_applicants_filtered[col] = df_applicants_filtered[col].astype(str).apply(clean_text)
# /tmp/ipykernel_626/2126122218.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_applicants_filtered[col] = df_applicants_filtered[col].astype(str).apply(clean_text)
# /tmp/ipykernel_626/2126122218.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_applicants_filtered[col] = df_applicants_filtered[col].astype(str).apply(clean_text)
# /tmp/ipykernel_626/2126122218.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_applicants_filtered[col] = df_applicants_filtered[col].astype(str).apply(clean_text)
# /tmp/ipykernel_626/2126122218.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_applicants_filtered[col] = df_applicants_filtered[col].astype(str).apply(clean_text)
# /tmp/ipykernel_626/2126122218.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_applicants_filtered[col] = df_applicants_filtered[col].astype(str).apply(clean_text)
# /tmp/ipykernel_626/2126122218.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vagas_filtered[col] = df_vagas_filtered[col].astype(str).apply(clean_text)
# /tmp/ipykernel_626/2126122218.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vagas_filtered[col] = df_vagas_filtered[col].astype(str).apply(clean_text)
# /tmp/ipykernel_626/2126122218.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vagas_filtered[col] = df_vagas_filtered[col].astype(str).apply(clean_text)
# /tmp/ipykernel_626/2126122218.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vagas_filtered[col] = df_vagas_filtered[col].astype(str).apply(clean_text)
# /tmp/ipykernel_626/2126122218.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vagas_filtered[col] = df_vagas_filtered[col].astype(str).apply(clean_text)
# /tmp/ipykernel_626/2126122218.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vagas_filtered[col] = df_vagas_filtered[col].astype(str).apply(clean_text)
# /tmp/ipykernel_626/2126122218.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vagas_filtered[col] = df_vagas_filtered[col].astype(str).apply(clean_text)
# /tmp/ipykernel_626/2126122218.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vagas_filtered[col] = df_vagas_filtered[col].astype(str).apply(clean_text)
# Cleaned df_applicants_filtered:
#                       nome endereco         titulo_profissional  \
# 0       carolina aparecida
# 1              eduardo rio    paulo     analista administrativo
# 2  pedro henrique carvalho    paulo  administrativo  financeiro
# 3           thiago barbosa    paulo         área administrativa
# 4               diogo neve
#
#      area_atuacao conhecimentos_tecnicos  \
# 0
# 1  administrativa
# 2  administrativa
# 3  administrativa
# 4
#
#                                        certificacoes outras_certificacoes  \
# 0
# 1
# 2  m 77418 mo microsoft office word 2013 m 77420 ...
# 3
# 4
#
#   nivel_profissional   nivel_ingles nivel_espanhol
# 0
# 1                            nenhum         nenhum
# 2                     intermediário         básico
# 3                            nenhum         nenhum
# 4
#
# Cleaned df_vagas_filtered:
#                                      titulo_vaga cidade nivel profissional  \
# 0                                operation lead   paulo             sênior
# 1                          consultor ppqm sênior  paulo             sênior
# 2                            analista pljr c sql  paulo           analista
# 3                  technical architect  11894809  paulo           analista
# 4  consultor sap authorization bca pleno  sênior  paulo             sênior
#
#     nivel_ingles nivel_espanhol                   areas_atuacao  \
# 0       avançado        fluente        ti  sistemas ferramentas
# 1        fluente         nenhum  ti  desenvolvimentoprogramação
# 2         nenhum  intermediário        ti  sistemas ferramentas
# 3         básico         básico                    ti  projetos
# 4  intermediário         nenhum                         ti  sap
#
#                                principais_atividades  \
# 0  operation lead\n\nroles  responsibilities\n th...
# 1  consultor ppqm sr\n\n consultor ppqm sênior ex...
# 2  descrição  atividades\n\no monitoramento inter...
# 3  descriçãocomentário architecture framework  re...
# 4  experiência consultor sap authorization bca\np...
#
#               competencia_tecnicas_e_comportamentais  \
# 0  require skills\n prior experience in cloud inf...
# 1   consultor ppqm sênior experiencia projetos ro...
# 2  requisitos mandatórios\n\no conhecimentos técn...
# 3  descriçãocomentário architecture framework  re...
# 4  experiência consultor sap authorization bca\np...
#
#                                   demais_observacoes  \
# 0                     100 remoto período  5  6 meses
# 1                         início imediato  fim jan22
# 2  localização remoto perfil analista pleno jr pe...
# 3  budget rate  indicate currency and type hourly...
# 4  contratação clt full decision locação remota s...
#
#   habilidades_comportamentais_necessarias
# 0                                     nan
# 1                                     nan
# 2                                     nan
# 3                                     nan
# 4                                     nan
# /tmp/ipykernel_626/2126122218.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vagas_filtered[col] = df_vagas_filtered[col].astype(str).apply(clean_text)
# /tmp/ipykernel_626/2126122218.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vagas_filtered[col] = df_vagas_filtered[col].astype(str).apply(clean_text)
